# %%
#!pip install scikit-learn==0.23.2
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import sys
from pickle import load
import lightgbm as lgb
from sklearn import ensemble
import xgboost as xgb
from sklearn import neighbors
import joblib
import pickle
from sklearn.metrics import r2_score
import matplotlib.lines as mlines
import matplotlib.transforms as mtransforms

# %%
#Load trained ML models and scalers

#ML models for predicting elastic shear buckling load, Vcr

#Support vector machine (SVR)
SVR_Vcr_model = joblib.load(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vcr\SVR\SlCh_Vcr_SVR_2021_02_02.joblib')
SVR_Vcr_scaler=pickle.load(open(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vcr\SVR\SlCh_Vcr_SVR_2021_02_02.pkl','rb'))

#Desision tree (DT)
DT_Vcr_model = joblib.load(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vcr\DT\SlCh_Vcr_DT_2021-02-08.joblib')
DT_Vcr_scaler=pickle.load(open(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vcr\DT\SlCh_Vcr_DT_2021-02-08.pkl','rb'))

#Random forest (RF)
RF_Vcr_model = joblib.load(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vcr\RF\SlCh_Vcr_RF_2021_02_04.joblib')
RF_Vcr_scaler=pickle.load(open(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vcr\RF\SlCh_Vcr_RF_2021_02_04.pkl','rb'))

#K-nearest neighbor (KNN)
KNN_Vcr_model = joblib.load(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vcr\KNN\SlCh_Vcr_KNN_2021-02-08.joblib')
KNN_Vcr_scaler=pickle.load(open(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vcr\KNN\SlCh_Vcr_KNN_2021-02-08.pkl','rb'))

#Gradient boosting regressor (GBR)
GBR_Vcr_model = joblib.load(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vcr\GBR\SlCh_Vcr_GBR_2021_02_03.joblib')
GBR_Vcr_scaler=pickle.load(open(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vcr\GBR\SlCh_Vcr_GBR_2021_02_03.pkl','rb'))

#Extreme gradient boosting (XGBoost)
XGBoost_Vcr_model = joblib.load(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vcr\XGBoost\SlCh_Vcr_XGBoost_2021_02_04.joblib')
XGBoost_Vcr_scaler=pickle.load(open(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vcr\XGBoost\SlCh_Vcr_XGBoost_2021_02_04.pkl','rb'))

#Light gradient boosting machine (LightGBM)
LightGBM_Vcr_model = joblib.load(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vcr\LightGBM\SlCh_Vcr_LightGBM_2021_02_04.joblib')
LightGBM_Vcr_scaler=pickle.load(open(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vcr\LightGBM\SlCh_Vcr_LightGBM_2021_02_04.pkl','rb'))

#Gradient boosting with categorical features support (CatBoost)
CatBoost_Vcr_model = joblib.load(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vcr\CatBoost\SlCh_Vcr_CatBoost_2021_02_06.joblib')
CatBoost_Vcr_scaler=pickle.load(open(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vcr\CatBoost\SlCh_Vcr_CatBoost_2021_02_06.pkl','rb'))

#Adaptive boosting (AdaBoost)
AdaBoost_Vcr_model = joblib.load(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vcr\AdaBoost\SlCh_Vcr_AdaBoost_2021-02-07.joblib')
AdaBoost_Vcr_scaler=pickle.load(open(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vcr\AdaBoost\SlCh_Vcr_AdaBoost_2021-02-07.pkl','rb'))

#ML models for predicting ultimate shear strength, Vn

#Support vector machine (SVR)
SVR_Vn_model = joblib.load(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vn\SVR\SlCh_Vn_SVR_2021_02_02.joblib')
SVR_Vn_scaler=pickle.load(open(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vn\SVR\SlCh_Vn_SVR_2021_02_02.pkl','rb'))

#Desision tree (DT)
DT_Vn_model = joblib.load(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vn\DT\SlCh_Vn_DT_2021-02-08.joblib')
DT_Vn_scaler=pickle.load(open(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vn\DT\SlCh_Vn_DT_2021-02-08.pkl','rb'))

#Random forest (RF)
RF_Vn_model = joblib.load(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vn\RF\SlCh_Vn_RF_2021_02_04.joblib')
RF_Vn_scaler=pickle.load(open(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vn\RF\SlCh_Vn_RF_2021_02_04.pkl','rb'))

#K-nearest neighbor (KNN)
KNN_Vn_model = joblib.load(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vn\KNN\SlCh_Vn_KNN_2021-02-08.joblib')
KNN_Vn_scaler=pickle.load(open(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vn\KNN\SlCh_Vn_KNN_2021-02-08.pkl','rb'))

#Gradient boosting regressor (GBR)
GBR_Vn_model = joblib.load(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vn\GBR\SlCh_Vn_GBR_2021_02_03.joblib')
GBR_Vn_scaler=pickle.load(open(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vn\GBR\SlCh_Vn_GBR_2021_02_03.pkl','rb'))

#Extreme gradient boosting (XGBoost)
XGBoost_Vn_model = joblib.load(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vn\XGBoost\SlCh_Vn_XGBoost_2021_02_04.joblib')
XGBoost_Vn_scaler=pickle.load(open(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vn\XGBoost\SlCh_Vn_XGBoost_2021_02_04.pkl','rb'))

#Light gradient boosting machine (LightGBM)
LightGBM_Vn_model = joblib.load(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vn\LightGBM\SlCh_Vn_LightGBM_2021_02_04.joblib')
LightGBM_Vn_scaler=pickle.load(open(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vn\LightGBM\SlCh_Vn_LightGBM_2021_02_04.pkl','rb'))

#Gradient boosting with categorical features support (CatBoost)
CatBoost_Vn_model = joblib.load(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vn\CatBoost\SlCh_Vn_CatBoost_2021_02_06.joblib')
CatBoost_Vn_scaler=pickle.load(open(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vn\CatBoost\SlCh_Vn_CatBoost_2021_02_06.pkl','rb'))

#Adaptive boosting (AdaBoost)
AdaBoost_Vn_model = joblib.load(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vn\AdaBoost\SlCh_Vn_AdaBoost_2021-02-07.joblib')
AdaBoost_Vn_scaler=pickle.load(open(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Vn\AdaBoost\SlCh_Vn_AdaBoost_2021-02-07.pkl','rb'))

# %%
#Show comparisons of ML model predictions with the FE simulation results used for the model development

#Read the datasets
flat_perf_R=pd.read_csv(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Datasets\CSV\FEA_Flat_Perf_R_Dataset.csv')
stiff_perf_R=pd.read_csv(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Datasets\CSV\FEA_Stiff_Perf_R_Dataset.csv')
flat_perf_TS=pd.read_csv(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Datasets\CSV\FEA_Flat_Perf_TS_Dataset.csv')
stiff_perf_TS=pd.read_csv(r'C:\Users\vitde\Documents\Vitaliy\ANN\Shear\Datasets\CSV\FEA_Stiff_Perf_TS_Dataset.csv')

#Drop NaN values from the datasets
flat_perf_R.dropna(axis=0, how='all',inplace=True)
flat_perf_R.dropna(axis=1, how='all',inplace=True)
stiff_perf_R.dropna(axis=0, how='all',inplace=True)
stiff_perf_R.dropna(axis=1, how='all',inplace=True)
flat_perf_TS.dropna(axis=0, how='all',inplace=True)
flat_perf_TS.dropna(axis=1, how='all',inplace=True)
stiff_perf_TS.dropna(axis=0, how='all',inplace=True)
stiff_perf_TS.dropna(axis=1, how='all',inplace=True)

#Divide datasets into input and output parameters
flat_perf_R_Vcr_y=flat_perf_R.drop(['Model_ID','D','B','B1','t','Lsl','Wsl','Ssl','Bsl','N','n','Fy','BC','r','a_h','hst','V'],axis=1)
flat_perf_R_Vcr_x=flat_perf_R.drop(['Model_ID','r','Vcr','V','B1','Fy'],axis=1)

stiff_perf_R_Vcr_y=stiff_perf_R.drop(['Model_ID','D','B','B1','t','Lsl','Wsl','Ssl','Bsl','N','n','Fy','BC','r','a_h','hst','V'],axis=1)
stiff_perf_R_Vcr_x=stiff_perf_R.drop(['Model_ID','r','Vcr','V','B1','Fy'],axis=1)

flat_perf_TS_Vcr_y=flat_perf_TS.drop(['Model_ID','D','B','B1','t','Lsl','Wsl','Ssl','Bsl','N','n','Fy','BC','r','a_h','hst','V'],axis=1)
flat_perf_TS_Vcr_x=flat_perf_TS.drop(['Model_ID','r','Vcr','V','B1','Fy'],axis=1)

stiff_perf_TS_Vcr_y=stiff_perf_TS.drop(['Model_ID','D','B','B1','t','Lsl','Wsl','Ssl','Bsl','N','n','Fy','BC','r','a_h','hst','V'],axis=1)
stiff_perf_TS_Vcr_x=stiff_perf_TS.drop(['Model_ID','r','Vcr','V','B1','Fy'],axis=1)

X_Vcr=pd.concat([flat_perf_R_Vcr_x,stiff_perf_R_Vcr_x,flat_perf_TS_Vcr_x,stiff_perf_TS_Vcr_x]).values
Y_Vcr=pd.concat([flat_perf_R_Vcr_y,stiff_perf_R_Vcr_y,flat_perf_TS_Vcr_y,stiff_perf_TS_Vcr_y]).values.ravel()

flat_perf_R_Vn_y=flat_perf_R.drop(['Model_ID','D','B','B1','t','Lsl','Wsl','Ssl','Bsl','N','n','Fy','BC','r','a_h','hst','Vcr'],axis=1)
flat_perf_R_Vn_x=flat_perf_R.drop(['Model_ID','r','Vcr','V','B1'],axis=1)

stiff_perf_R_Vn_y=stiff_perf_R.drop(['Model_ID','D','B','B1','t','Lsl','Wsl','Ssl','Bsl','N','n','Fy','BC','r','a_h','hst','Vcr'],axis=1)
stiff_perf_R_Vn_x=stiff_perf_R.drop(['Model_ID','r','Vcr','V','B1'],axis=1)

flat_perf_TS_Vn_y=flat_perf_TS.drop(['Model_ID','D','B','B1','t','Lsl','Wsl','Ssl','Bsl','N','n','Fy','BC','r','a_h','hst','Vcr'],axis=1)
flat_perf_TS_Vn_x=flat_perf_TS.drop(['Model_ID','r','Vcr','V','B1'],axis=1)

stiff_perf_TS_Vn_y=stiff_perf_TS.drop(['Model_ID','D','B','B1','t','Lsl','Wsl','Ssl','Bsl','N','n','Fy','BC','r','a_h','hst','Vcr'],axis=1)
stiff_perf_TS_Vn_x=stiff_perf_TS.drop(['Model_ID','r','Vcr','V','B1'],axis=1)

X_Vn=pd.concat([flat_perf_R_Vn_x,stiff_perf_R_Vn_x,flat_perf_TS_Vn_x,stiff_perf_TS_Vn_x]).values
Y_Vn=pd.concat([flat_perf_R_Vn_y,stiff_perf_R_Vn_y,flat_perf_TS_Vn_y,stiff_perf_TS_Vn_y]).values.ravel()

# %%
#Scale input parameters

X_Vcr_SVR=SVR_Vcr_scaler.transform(X_Vcr)
X_Vcr_DT=DT_Vcr_scaler.transform(X_Vcr)
X_Vcr_RF=RF_Vcr_scaler.transform(X_Vcr)
X_Vcr_KNN=KNN_Vcr_scaler.transform(X_Vcr)
X_Vcr_GBR=GBR_Vcr_scaler.transform(X_Vcr)
X_Vcr_XGBoost=XGBoost_Vcr_scaler.transform(X_Vcr)
X_Vcr_LightGBM=LightGBM_Vcr_scaler.transform(X_Vcr)
X_Vcr_CatBoost=CatBoost_Vcr_scaler.transform(X_Vcr)
X_Vcr_AdaBoost=AdaBoost_Vcr_scaler.transform(X_Vcr)

X_Vn_SVR=SVR_Vn_scaler.transform(X_Vn)
X_Vn_DT=DT_Vn_scaler.transform(X_Vn)
X_Vn_RF=RF_Vn_scaler.transform(X_Vn)
X_Vn_KNN=KNN_Vn_scaler.transform(X_Vn)
X_Vn_GBR=GBR_Vn_scaler.transform(X_Vn)
X_Vn_XGBoost=XGBoost_Vn_scaler.transform(X_Vn)
X_Vn_LightGBM=LightGBM_Vn_scaler.transform(X_Vn)
X_Vn_CatBoost=CatBoost_Vn_scaler.transform(X_Vn)
X_Vn_AdaBoost=AdaBoost_Vn_scaler.transform(X_Vn)

# %%
#Predict elastic shear buckling loads, Vcr, for samples in the dataset using the developed ML models
Y_Vcr_SVR=SVR_Vcr_model.predict(X_Vcr_SVR)
Y_Vcr_DT=DT_Vcr_model.predict(X_Vcr_DT)
Y_Vcr_RF=RF_Vcr_model.predict(X_Vcr_RF)
Y_Vcr_KNN=KNN_Vcr_model.predict(X_Vcr_KNN)
Y_Vcr_GBR=GBR_Vcr_model.predict(X_Vcr_GBR)
Y_Vcr_XGBoost=XGBoost_Vcr_model.predict(X_Vcr_XGBoost)
Y_Vcr_LightGBM=LightGBM_Vcr_model.predict(X_Vcr_LightGBM)
Y_Vcr_CatBoost=CatBoost_Vcr_model.predict(X_Vcr_CatBoost)
Y_Vcr_AdaBoost=AdaBoost_Vcr_model.predict(X_Vcr_AdaBoost)

#Predict ultimate shear strength, Vn, for samples in the dataset using the developed ML models
Y_Vn_SVR=SVR_Vn_model.predict(X_Vn_SVR)
Y_Vn_DT=DT_Vn_model.predict(X_Vn_DT)
Y_Vn_RF=RF_Vn_model.predict(X_Vn_RF)
Y_Vn_KNN=KNN_Vn_model.predict(X_Vn_KNN)
Y_Vn_GBR=GBR_Vn_model.predict(X_Vn_GBR)
Y_Vn_XGBoost=XGBoost_Vn_model.predict(X_Vn_XGBoost)
Y_Vn_LightGBM=LightGBM_Vn_model.predict(X_Vn_LightGBM)
Y_Vn_CatBoost=CatBoost_Vn_model.predict(X_Vn_CatBoost)
Y_Vn_AdaBoost=AdaBoost_Vn_model.predict(X_Vn_AdaBoost)

# %%
#Calculate performance metrics for the ML predictions

#Elastic shear buckling load, Vcr
R2_SVR_Vcr=r2_score(Y_Vcr,Y_Vcr_SVR)
SVR_Vcr_FEA_min=np.ndarray.min(Y_Vcr_SVR/Y_Vcr)
SVR_Vcr_FEA_max=np.ndarray.max(Y_Vcr_SVR/Y_Vcr)
SVR_Vcr_FEA_mean=np.ndarray.mean(Y_Vcr_SVR/Y_Vcr)
SVR_Vcr_FEA_std=np.ndarray.std(Y_Vcr_SVR/Y_Vcr)
SVR_Vcr_FEA_COV=SVR_Vcr_FEA_std/SVR_Vcr_FEA_mean

R2_DT_Vcr=r2_score(Y_Vcr,Y_Vcr_DT)
DT_Vcr_FEA_min=np.ndarray.min(Y_Vcr_DT/Y_Vcr)
DT_Vcr_FEA_max=np.ndarray.max(Y_Vcr_DT/Y_Vcr)
DT_Vcr_FEA_mean=np.ndarray.mean(Y_Vcr_DT/Y_Vcr)
DT_Vcr_FEA_std=np.ndarray.std(Y_Vcr_DT/Y_Vcr)
DT_Vcr_FEA_COV=DT_Vcr_FEA_std/DT_Vcr_FEA_mean

R2_RF_Vcr=r2_score(Y_Vcr,Y_Vcr_RF)
RF_Vcr_FEA_min=np.ndarray.min(Y_Vcr_RF/Y_Vcr)
RF_Vcr_FEA_max=np.ndarray.max(Y_Vcr_RF/Y_Vcr)
RF_Vcr_FEA_mean=np.ndarray.mean(Y_Vcr_RF/Y_Vcr)
RF_Vcr_FEA_std=np.ndarray.std(Y_Vcr_RF/Y_Vcr)
RF_Vcr_FEA_COV=RF_Vcr_FEA_std/RF_Vcr_FEA_mean

R2_KNN_Vcr=r2_score(Y_Vcr,Y_Vcr_KNN)
KNN_Vcr_FEA_min=np.ndarray.min(Y_Vcr_KNN/Y_Vcr)
KNN_Vcr_FEA_max=np.ndarray.max(Y_Vcr_KNN/Y_Vcr)
KNN_Vcr_FEA_mean=np.ndarray.mean(Y_Vcr_KNN/Y_Vcr)
KNN_Vcr_FEA_std=np.ndarray.std(Y_Vcr_KNN/Y_Vcr)
KNN_Vcr_FEA_COV=KNN_Vcr_FEA_std/KNN_Vcr_FEA_mean

R2_GBR_Vcr=r2_score(Y_Vcr,Y_Vcr_GBR)
GBR_Vcr_FEA_min=np.ndarray.min(Y_Vcr_GBR/Y_Vcr)
GBR_Vcr_FEA_max=np.ndarray.max(Y_Vcr_GBR/Y_Vcr)
GBR_Vcr_FEA_mean=np.ndarray.mean(Y_Vcr_GBR/Y_Vcr)
GBR_Vcr_FEA_std=np.ndarray.std(Y_Vcr_GBR/Y_Vcr)
GBR_Vcr_FEA_COV=GBR_Vcr_FEA_std/GBR_Vcr_FEA_mean

R2_XGBoost_Vcr=r2_score(Y_Vcr,Y_Vcr_XGBoost)
XGBoost_Vcr_FEA_min=np.ndarray.min(Y_Vcr_XGBoost/Y_Vcr)
XGBoost_Vcr_FEA_max=np.ndarray.max(Y_Vcr_XGBoost/Y_Vcr)
XGBoost_Vcr_FEA_mean=np.ndarray.mean(Y_Vcr_XGBoost/Y_Vcr)
XGBoost_Vcr_FEA_std=np.ndarray.std(Y_Vcr_XGBoost/Y_Vcr)
XGBoost_Vcr_FEA_COV=XGBoost_Vcr_FEA_std/XGBoost_Vcr_FEA_mean

R2_LightGBM_Vcr=r2_score(Y_Vcr,Y_Vcr_LightGBM)
LightGBM_Vcr_FEA_min=np.ndarray.min(Y_Vcr_LightGBM/Y_Vcr)
LightGBM_Vcr_FEA_max=np.ndarray.max(Y_Vcr_LightGBM/Y_Vcr)
LightGBM_Vcr_FEA_mean=np.ndarray.mean(Y_Vcr_LightGBM/Y_Vcr)
LightGBM_Vcr_FEA_std=np.ndarray.std(Y_Vcr_LightGBM/Y_Vcr)
LightGBM_Vcr_FEA_COV=LightGBM_Vcr_FEA_std/LightGBM_Vcr_FEA_mean

R2_CatBoost_Vcr=r2_score(Y_Vcr,Y_Vcr_CatBoost)
CatBoost_Vcr_FEA_min=np.ndarray.min(Y_Vcr_CatBoost/Y_Vcr)
CatBoost_Vcr_FEA_max=np.ndarray.max(Y_Vcr_CatBoost/Y_Vcr)
CatBoost_Vcr_FEA_mean=np.ndarray.mean(Y_Vcr_CatBoost/Y_Vcr)
CatBoost_Vcr_FEA_std=np.ndarray.std(Y_Vcr_CatBoost/Y_Vcr)
CatBoost_Vcr_FEA_COV=CatBoost_Vcr_FEA_std/CatBoost_Vcr_FEA_mean

R2_AdaBoost_Vcr=r2_score(Y_Vcr,Y_Vcr_AdaBoost)
AdaBoost_Vcr_FEA_min=np.ndarray.min(Y_Vcr_AdaBoost/Y_Vcr)
AdaBoost_Vcr_FEA_max=np.ndarray.max(Y_Vcr_AdaBoost/Y_Vcr)
AdaBoost_Vcr_FEA_mean=np.ndarray.mean(Y_Vcr_AdaBoost/Y_Vcr)
AdaBoost_Vcr_FEA_std=np.ndarray.std(Y_Vcr_AdaBoost/Y_Vcr)
AdaBoost_Vcr_FEA_COV=AdaBoost_Vcr_FEA_std/AdaBoost_Vcr_FEA_mean


#Ultimate shear strength, Vn
R2_SVR_Vn=r2_score(Y_Vn,Y_Vn_SVR)
SVR_Vn_FEA_min=np.ndarray.min(Y_Vn_SVR/Y_Vn)
SVR_Vn_FEA_max=np.ndarray.max(Y_Vn_SVR/Y_Vn)
SVR_Vn_FEA_mean=np.ndarray.mean(Y_Vn_SVR/Y_Vn)
SVR_Vn_FEA_std=np.ndarray.std(Y_Vn_SVR/Y_Vn)
SVR_Vn_FEA_COV=SVR_Vn_FEA_std/SVR_Vn_FEA_mean

R2_DT_Vn=r2_score(Y_Vn,Y_Vn_DT)
DT_Vn_FEA_min=np.ndarray.min(Y_Vn_DT/Y_Vn)
DT_Vn_FEA_max=np.ndarray.max(Y_Vn_DT/Y_Vn)
DT_Vn_FEA_mean=np.ndarray.mean(Y_Vn_DT/Y_Vn)
DT_Vn_FEA_std=np.ndarray.std(Y_Vn_DT/Y_Vn)
DT_Vn_FEA_COV=DT_Vn_FEA_std/DT_Vn_FEA_mean

R2_RF_Vn=r2_score(Y_Vn,Y_Vn_RF)
RF_Vn_FEA_min=np.ndarray.min(Y_Vn_RF/Y_Vn)
RF_Vn_FEA_max=np.ndarray.max(Y_Vn_RF/Y_Vn)
RF_Vn_FEA_mean=np.ndarray.mean(Y_Vn_RF/Y_Vn)
RF_Vn_FEA_std=np.ndarray.std(Y_Vn_RF/Y_Vn)
RF_Vn_FEA_COV=RF_Vn_FEA_std/RF_Vn_FEA_mean

R2_KNN_Vn=r2_score(Y_Vn,Y_Vn_KNN)
KNN_Vn_FEA_min=np.ndarray.min(Y_Vn_KNN/Y_Vn)
KNN_Vn_FEA_max=np.ndarray.max(Y_Vn_KNN/Y_Vn)
KNN_Vn_FEA_mean=np.ndarray.mean(Y_Vn_KNN/Y_Vn)
KNN_Vn_FEA_std=np.ndarray.std(Y_Vn_KNN/Y_Vn)
KNN_Vn_FEA_COV=KNN_Vn_FEA_std/KNN_Vn_FEA_mean

R2_GBR_Vn=r2_score(Y_Vn,Y_Vn_GBR)
GBR_Vn_FEA_min=np.ndarray.min(Y_Vn_GBR/Y_Vn)
GBR_Vn_FEA_max=np.ndarray.max(Y_Vn_GBR/Y_Vn)
GBR_Vn_FEA_mean=np.ndarray.mean(Y_Vn_GBR/Y_Vn)
GBR_Vn_FEA_std=np.ndarray.std(Y_Vn_GBR/Y_Vn)
GBR_Vn_FEA_COV=GBR_Vn_FEA_std/GBR_Vn_FEA_mean

R2_XGBoost_Vn=r2_score(Y_Vn,Y_Vn_XGBoost)
XGBoost_Vn_FEA_min=np.ndarray.min(Y_Vn_XGBoost/Y_Vn)
XGBoost_Vn_FEA_max=np.ndarray.max(Y_Vn_XGBoost/Y_Vn)
XGBoost_Vn_FEA_mean=np.ndarray.mean(Y_Vn_XGBoost/Y_Vn)
XGBoost_Vn_FEA_std=np.ndarray.std(Y_Vn_XGBoost/Y_Vn)
XGBoost_Vn_FEA_COV=XGBoost_Vn_FEA_std/XGBoost_Vn_FEA_mean

R2_LightGBM_Vn=r2_score(Y_Vn,Y_Vn_LightGBM)
LightGBM_Vn_FEA_min=np.ndarray.min(Y_Vn_LightGBM/Y_Vn)
LightGBM_Vn_FEA_max=np.ndarray.max(Y_Vn_LightGBM/Y_Vn)
LightGBM_Vn_FEA_mean=np.ndarray.mean(Y_Vn_LightGBM/Y_Vn)
LightGBM_Vn_FEA_std=np.ndarray.std(Y_Vn_LightGBM/Y_Vn)
LightGBM_Vn_FEA_COV=LightGBM_Vn_FEA_std/LightGBM_Vn_FEA_mean

R2_CatBoost_Vn=r2_score(Y_Vn,Y_Vn_CatBoost)
CatBoost_Vn_FEA_min=np.ndarray.min(Y_Vn_CatBoost/Y_Vn)
CatBoost_Vn_FEA_max=np.ndarray.max(Y_Vn_CatBoost/Y_Vn)
CatBoost_Vn_FEA_mean=np.ndarray.mean(Y_Vn_CatBoost/Y_Vn)
CatBoost_Vn_FEA_std=np.ndarray.std(Y_Vn_CatBoost/Y_Vn)
CatBoost_Vn_FEA_COV=CatBoost_Vn_FEA_std/CatBoost_Vn_FEA_mean

R2_AdaBoost_Vn=r2_score(Y_Vn,Y_Vn_AdaBoost)
AdaBoost_Vn_FEA_min=np.ndarray.min(Y_Vn_AdaBoost/Y_Vn)
AdaBoost_Vn_FEA_max=np.ndarray.max(Y_Vn_AdaBoost/Y_Vn)
AdaBoost_Vn_FEA_mean=np.ndarray.mean(Y_Vn_AdaBoost/Y_Vn)
AdaBoost_Vn_FEA_std=np.ndarray.std(Y_Vn_AdaBoost/Y_Vn)
AdaBoost_Vn_FEA_COV=AdaBoost_Vn_FEA_std/AdaBoost_Vn_FEA_mean

# %%
#Comparison plots for the elastic shear buckling load, Vcr
# %matplotlib inline
f1 = plt.figure(figsize=(10,10), dpi=200)

#------------------------------------------------------------------------------
#  SVR
#------------------------------------------------------------------------------

ax1 = f1.add_subplot(3,3,1)
ax1.scatter(0.001*Y_Vcr_SVR, 0.001*Y_Vcr, s=20, edgecolors='b', facecolor='none', linewidth=0.5, alpha=1)
ax1.set_aspect('equal')
ax1.set_xlabel('Vcr (Prediction) (kN)', fontsize=9)
ax1.set_ylabel('Vcr (FEA) (kN)', fontsize=9)
ax1.xaxis.set_ticks(np.arange(0, 351, 50))
ax1.yaxis.set_ticks(np.arange(0, 351, 50))
ax1.tick_params(axis='both', which='major', labelsize=9, direction='in', width=0.5)
for axis in ['top','bottom','left','right']:
  ax1.spines[axis].set_linewidth(0.5)

line = mlines.Line2D([0, 1], [0, 1], color='r', linestyle=':', linewidth=0.75, alpha=1)
transform = ax1.transAxes
line.set_transform(transform)
ax1.add_line(line)
ax1.text(50,300,'SVR', fontsize=8, color='k')
ax1.text(25,225,'$R^2$=%.3f' %R2_SVR_Vcr, fontsize=8, color='k')
ax1.text(200,115,'Prediction/FEA', fontsize=8, color='k')
ax1.text(210,90,'min=%.2f' %SVR_Vcr_FEA_min, fontsize=8, color='k')
ax1.text(210,65,'max=%.2f' %SVR_Vcr_FEA_max, fontsize=8, color='k')
ax1.text(210,40,'mean=%.2f' %SVR_Vcr_FEA_mean, fontsize=8, color='k')
ax1.text(210,15,'COV=%.3f' %SVR_Vcr_FEA_COV, fontsize=8, color='k')

#------------------------------------------------------------------------------
#  DT
#------------------------------------------------------------------------------

ax2 = f1.add_subplot(3,3,2)
ax2.scatter(0.001*Y_Vcr_DT, 0.001*Y_Vcr, s=20, edgecolors='b', facecolor='none', linewidth=0.5, alpha=1)
ax2.set_aspect('equal')
ax2.set_xlabel('Vcr (Prediction) (kN)', fontsize=9)
ax2.set_ylabel('Vcr (FEA) (kN)', fontsize=9)
ax2.xaxis.set_ticks(np.arange(0, 351, 50))
ax2.yaxis.set_ticks(np.arange(0, 351, 50))
ax2.tick_params(axis='both', which='major', labelsize=9, direction='in', width=0.5)
for axis in ['top','bottom','left','right']:
  ax2.spines[axis].set_linewidth(0.5)

line = mlines.Line2D([0, 1], [0, 1], color='r', linestyle=':', linewidth=0.75, alpha=1)
transform = ax2.transAxes
line.set_transform(transform)
ax2.add_line(line)
ax2.text(50,300,'DT', fontsize=8, color='k')
ax2.text(25,225,'$R^2$=%.3f' %R2_DT_Vcr, fontsize=8, color='k')
ax2.text(200,115,'Prediction/FEA', fontsize=8, color='k')
ax2.text(210,90,'min=%.2f' %DT_Vcr_FEA_min, fontsize=8, color='k')
ax2.text(210,65,'max=%.2f' %DT_Vcr_FEA_max, fontsize=8, color='k')
ax2.text(210,40,'mean=%.2f' %DT_Vcr_FEA_mean, fontsize=8, color='k')
ax2.text(210,15,'COV=%.3f' %DT_Vcr_FEA_COV, fontsize=8, color='k')

#------------------------------------------------------------------------------
#  RF
#------------------------------------------------------------------------------

ax3 = f1.add_subplot(3,3,3)
ax3.scatter(0.001*Y_Vcr_RF, 0.001*Y_Vcr, s=20, edgecolors='b', facecolor='none', linewidth=0.5, alpha=1)
ax3.set_aspect('equal')
ax3.set_xlabel('Vcr (Prediction) (kN)', fontsize=9)
ax3.set_ylabel('Vcr (FEA) (kN)', fontsize=9)
ax3.xaxis.set_ticks(np.arange(0, 351, 50))
ax3.yaxis.set_ticks(np.arange(0, 351, 50))
ax3.tick_params(axis='both', which='major', labelsize=9, direction='in', width=0.5)
for axis in ['top','bottom','left','right']:
  ax3.spines[axis].set_linewidth(0.5)

line = mlines.Line2D([0, 1], [0, 1], color='r', linestyle=':', linewidth=0.75, alpha=1)
transform = ax3.transAxes
line.set_transform(transform)
ax3.add_line(line)
ax3.text(50,300,'RF', fontsize=8, color='k')
ax3.text(25,225,'$R^2$=%.3f' %R2_RF_Vcr, fontsize=8, color='k')
ax3.text(200,115,'Prediction/FEA', fontsize=8, color='k')
ax3.text(210,90,'min=%.2f' %RF_Vcr_FEA_min, fontsize=8, color='k')
ax3.text(210,65,'max=%.2f' %RF_Vcr_FEA_max, fontsize=8, color='k')
ax3.text(210,40,'mean=%.2f' %RF_Vcr_FEA_mean, fontsize=8, color='k')
ax3.text(210,15,'COV=%.3f' %RF_Vcr_FEA_COV, fontsize=8, color='k')


#------------------------------------------------------------------------------
#  KNN
#------------------------------------------------------------------------------

ax4 = f1.add_subplot(3,3,4)
ax4.scatter(0.001*Y_Vcr_KNN, 0.001*Y_Vcr, s=20, edgecolors='b', facecolor='none', linewidth=0.5, alpha=1)
ax4.set_aspect('equal')
ax4.set_xlabel('Vcr (Prediction) (kN)', fontsize=9)
ax4.set_ylabel('Vcr (FEA) (kN)', fontsize=9)
ax4.xaxis.set_ticks(np.arange(0, 351, 50))
ax4.yaxis.set_ticks(np.arange(0, 351, 50))
ax4.tick_params(axis='both', which='major', labelsize=9, direction='in', width=0.5)
for axis in ['top','bottom','left','right']:
  ax4.spines[axis].set_linewidth(0.5)

line = mlines.Line2D([0, 1], [0, 1], color='r', linestyle=':', linewidth=0.75, alpha=1)
transform = ax4.transAxes
line.set_transform(transform)
ax4.add_line(line)
ax4.text(50,300,'KNN', fontsize=8, color='k')
ax4.text(25,225,'$R^2$=%.3f' %R2_KNN_Vcr, fontsize=8, color='k')
ax4.text(200,115,'Prediction/FEA', fontsize=8, color='k')
ax4.text(210,90,'min=%.2f' %KNN_Vcr_FEA_min, fontsize=8, color='k')
ax4.text(210,65,'max=%.2f' %KNN_Vcr_FEA_max, fontsize=8, color='k')
ax4.text(210,40,'mean=%.2f' %KNN_Vcr_FEA_mean, fontsize=8, color='k')
ax4.text(210,15,'COV=%.3f' %KNN_Vcr_FEA_COV, fontsize=8, color='k')

#------------------------------------------------------------------------------
#  GBR
#------------------------------------------------------------------------------

ax5 = f1.add_subplot(3,3,5)
ax5.scatter(0.001*Y_Vcr_GBR, 0.001*Y_Vcr, s=20, edgecolors='b', facecolor='none', linewidth=0.5, alpha=1)
ax5.set_aspect('equal')
ax5.set_xlabel('Vcr (Prediction) (kN)', fontsize=9)
ax5.set_ylabel('Vcr (FEA) (kN)', fontsize=9)
ax5.xaxis.set_ticks(np.arange(0, 351, 50))
ax5.yaxis.set_ticks(np.arange(0, 351, 50))
ax5.tick_params(axis='both', which='major', labelsize=9, direction='in', width=0.5)
for axis in ['top','bottom','left','right']:
  ax5.spines[axis].set_linewidth(0.5)

line = mlines.Line2D([0, 1], [0, 1], color='r', linestyle=':', linewidth=0.75, alpha=1)
transform = ax5.transAxes
line.set_transform(transform)
ax5.add_line(line)
ax5.text(50,300,'GBR', fontsize=8, color='k')
ax5.text(25,225,'$R^2$=%.3f' %R2_GBR_Vcr, fontsize=8, color='k')
ax5.text(200,115,'Prediction/FEA', fontsize=8, color='k')
ax5.text(210,90,'min=%.2f' %GBR_Vcr_FEA_min, fontsize=8, color='k')
ax5.text(210,65,'max=%.2f' %GBR_Vcr_FEA_max, fontsize=8, color='k')
ax5.text(210,40,'mean=%.2f' %GBR_Vcr_FEA_mean, fontsize=8, color='k')
ax5.text(210,15,'COV=%.3f' %GBR_Vcr_FEA_COV, fontsize=8, color='k')

#------------------------------------------------------------------------------
#  XGBoost
#------------------------------------------------------------------------------

ax6 = f1.add_subplot(3,3,6)
ax6.scatter(0.001*Y_Vcr_XGBoost, 0.001*Y_Vcr, s=20, edgecolors='b', facecolor='none', linewidth=0.5, alpha=1)
ax6.set_aspect('equal')
ax6.set_xlabel('Vcr (Prediction) (kN)', fontsize=9)
ax6.set_ylabel('Vcr (FEA) (kN)', fontsize=9)
ax6.xaxis.set_ticks(np.arange(0, 351, 50))
ax6.yaxis.set_ticks(np.arange(0, 351, 50))
ax6.tick_params(axis='both', which='major', labelsize=9, direction='in', width=0.5)
for axis in ['top','bottom','left','right']:
  ax6.spines[axis].set_linewidth(0.5)

line = mlines.Line2D([0, 1], [0, 1], color='r', linestyle=':', linewidth=0.75, alpha=1)
transform = ax6.transAxes
line.set_transform(transform)
ax6.add_line(line)
ax6.text(50,300,'XGBoost', fontsize=8, color='k')
ax6.text(25,225,'$R^2$=%.3f' %R2_XGBoost_Vcr, fontsize=8, color='k')
ax6.text(200,115,'Prediction/FEA', fontsize=8, color='k')
ax6.text(210,90,'min=%.2f' %XGBoost_Vcr_FEA_min, fontsize=8, color='k')
ax6.text(210,65,'max=%.2f' %XGBoost_Vcr_FEA_max, fontsize=8, color='k')
ax6.text(210,40,'mean=%.2f' %XGBoost_Vcr_FEA_mean, fontsize=8, color='k')
ax6.text(210,15,'COV=%.3f' %XGBoost_Vcr_FEA_COV, fontsize=8, color='k')

#------------------------------------------------------------------------------
#  LightGBM
#------------------------------------------------------------------------------

ax7 = f1.add_subplot(3,3,7)
ax7.scatter(0.001*Y_Vcr_LightGBM, 0.001*Y_Vcr, s=20, edgecolors='b', facecolor='none', linewidth=0.5, alpha=1)
ax7.set_aspect('equal')
ax7.set_xlabel('Vcr (Prediction) (kN)', fontsize=9)
ax7.set_ylabel('Vcr (FEA) (kN)', fontsize=9)
ax7.xaxis.set_ticks(np.arange(0, 351, 50))
ax7.yaxis.set_ticks(np.arange(0, 351, 50))
ax7.tick_params(axis='both', which='major', labelsize=9, direction='in', width=0.5)
for axis in ['top','bottom','left','right']:
  ax7.spines[axis].set_linewidth(0.5)

line = mlines.Line2D([0, 1], [0, 1], color='r', linestyle=':', linewidth=0.75, alpha=1)
transform = ax7.transAxes
line.set_transform(transform)
ax7.add_line(line)
ax7.text(50,300,'LightGBM', fontsize=8, color='k')
ax7.text(25,225,'$R^2$=%.3f' %R2_LightGBM_Vcr, fontsize=8, color='k')
ax7.text(200,115,'Prediction/FEA', fontsize=8, color='k')
ax7.text(210,90,'min=%.2f' %LightGBM_Vcr_FEA_min, fontsize=8, color='k')
ax7.text(210,65,'max=%.2f' %LightGBM_Vcr_FEA_max, fontsize=8, color='k')
ax7.text(210,40,'mean=%.2f' %LightGBM_Vcr_FEA_mean, fontsize=8, color='k')
ax7.text(210,15,'COV=%.3f' %LightGBM_Vcr_FEA_COV, fontsize=8, color='k')

#------------------------------------------------------------------------------
#  CatBoost
#------------------------------------------------------------------------------

ax8 = f1.add_subplot(3,3,8)
ax8.scatter(0.001*Y_Vcr_CatBoost, 0.001*Y_Vcr, s=20, edgecolors='b', facecolor='none', linewidth=0.5, alpha=1)
ax8.set_aspect('equal')
ax8.set_xlabel('Vcr (Prediction) (kN)', fontsize=9)
ax8.set_ylabel('Vcr (FEA) (kN)', fontsize=9)
ax8.xaxis.set_ticks(np.arange(0, 351, 50))
ax8.yaxis.set_ticks(np.arange(0, 351, 50))
ax8.tick_params(axis='both', which='major', labelsize=9, direction='in', width=0.5)
for axis in ['top','bottom','left','right']:
  ax8.spines[axis].set_linewidth(0.5)

line = mlines.Line2D([0, 1], [0, 1], color='r', linestyle=':', linewidth=0.75, alpha=1)
transform = ax8.transAxes
line.set_transform(transform)
ax8.add_line(line)
ax8.text(50,300,'CatBoost', fontsize=8, color='k')
ax8.text(25,225,'$R^2$=%.3f' %R2_CatBoost_Vcr, fontsize=8, color='k')
ax8.text(200,115,'Prediction/FEA', fontsize=8, color='k')
ax8.text(210,90,'min=%.2f' %CatBoost_Vcr_FEA_min, fontsize=8, color='k')
ax8.text(210,65,'max=%.2f' %CatBoost_Vcr_FEA_max, fontsize=8, color='k')
ax8.text(210,40,'mean=%.2f' %CatBoost_Vcr_FEA_mean, fontsize=8, color='k')
ax8.text(210,15,'COV=%.3f' %CatBoost_Vcr_FEA_COV, fontsize=8, color='k')

#------------------------------------------------------------------------------
#  AdaBoost
#------------------------------------------------------------------------------

ax9 = f1.add_subplot(3,3,9)
ax9.scatter(0.001*Y_Vcr_AdaBoost, 0.001*Y_Vcr, s=20, edgecolors='b', facecolor='none', linewidth=0.5, alpha=1)
ax9.set_aspect('equal')
ax9.set_xlabel('Vcr (Prediction) (kN)', fontsize=9)
ax9.set_ylabel('Vcr (FEA) (kN)', fontsize=9)
ax9.xaxis.set_ticks(np.arange(0, 351, 50))
ax9.yaxis.set_ticks(np.arange(0, 351, 50))
ax9.tick_params(axis='both', which='major', labelsize=9, direction='in', width=0.5)
for axis in ['top','bottom','left','right']:
  ax9.spines[axis].set_linewidth(0.5)

line = mlines.Line2D([0, 1], [0, 1], color='r', linestyle=':', linewidth=0.75, alpha=1)
transform = ax9.transAxes
line.set_transform(transform)
ax9.add_line(line)
ax9.text(50,300,'AdaBoost', fontsize=8, color='k')
ax9.text(25,225,'$R^2$=%.3f' %R2_AdaBoost_Vcr, fontsize=8, color='k')
ax9.text(200,115,'Prediction/FEA', fontsize=8, color='k')
ax9.text(210,90,'min=%.2f' %AdaBoost_Vcr_FEA_min, fontsize=8, color='k')
ax9.text(210,65,'max=%.2f' %AdaBoost_Vcr_FEA_max, fontsize=8, color='k')
ax9.text(210,40,'mean=%.2f' %AdaBoost_Vcr_FEA_mean, fontsize=8, color='k')
ax9.text(210,15,'COV=%.3f' %AdaBoost_Vcr_FEA_COV, fontsize=8, color='k')

f1.tight_layout()
plt.show()

# %%
#Comparison plots for the elastic shear buckling load, Vn
# %matplotlib inline
f1 = plt.figure(figsize=(10,10), dpi=200)

#------------------------------------------------------------------------------
#  SVR
#------------------------------------------------------------------------------

ax1 = f1.add_subplot(3,3,1)
ax1.scatter(0.001*Y_Vn_SVR, 0.001*Y_Vn, s=20, edgecolors='b', facecolor='none', linewidth=0.5, alpha=1)
ax1.set_aspect('equal')
ax1.set_xlabel('Vn (Prediction) (kN)', fontsize=9)
ax1.set_ylabel('Vn (FEA) (kN)', fontsize=9)
ax1.xaxis.set_ticks(np.arange(0, 121, 20))
ax1.yaxis.set_ticks(np.arange(0, 121, 20))
ax1.tick_params(axis='both', which='major', labelsize=9, direction='in', width=0.5)
for axis in ['top','bottom','left','right']:
  ax1.spines[axis].set_linewidth(0.5)

line = mlines.Line2D([0, 1], [0, 1], color='r', linestyle=':', linewidth=0.75, alpha=1)
transform = ax1.transAxes
line.set_transform(transform)
ax1.add_line(line)
ax1.text(20,100,'SVR', fontsize=8, color='k')
ax1.text(10,80,'$R^2$=%.3f' %R2_SVR_Vn, fontsize=8, color='k')
ax1.text(70,40,'Prediction/FEA', fontsize=8, color='k')
ax1.text(75,32,'min=%.2f' %SVR_Vn_FEA_min, fontsize=8, color='k')
ax1.text(75,24,'max=%.2f' %SVR_Vn_FEA_max, fontsize=8, color='k')
ax1.text(75,16,'mean=%.2f' %SVR_Vn_FEA_mean, fontsize=8, color='k')
ax1.text(75,8,'COV=%.3f' %SVR_Vn_FEA_COV, fontsize=8, color='k')

#------------------------------------------------------------------------------
#  DT
#------------------------------------------------------------------------------

ax2 = f1.add_subplot(3,3,2)
ax2.scatter(0.001*Y_Vn_DT, 0.001*Y_Vn, s=20, edgecolors='b', facecolor='none', linewidth=0.5, alpha=1)
ax2.set_aspect('equal')
ax2.set_xlabel('Vn (Prediction) (kN)', fontsize=9)
ax2.set_ylabel('Vn (FEA) (kN)', fontsize=9)
ax2.xaxis.set_ticks(np.arange(0, 121, 20))
ax2.yaxis.set_ticks(np.arange(0, 121, 20))
ax2.tick_params(axis='both', which='major', labelsize=9, direction='in', width=0.5)
for axis in ['top','bottom','left','right']:
  ax2.spines[axis].set_linewidth(0.5)

line = mlines.Line2D([0, 1], [0, 1], color='r', linestyle=':', linewidth=0.75, alpha=1)
transform = ax2.transAxes
line.set_transform(transform)
ax2.add_line(line)
ax2.text(20,100,'DT', fontsize=8, color='k')
ax2.text(10,80,'$R^2$=%.3f' %R2_DT_Vn, fontsize=8, color='k')
ax2.text(70,40,'Prediction/FEA', fontsize=8, color='k')
ax2.text(75,32,'min=%.2f' %DT_Vn_FEA_min, fontsize=8, color='k')
ax2.text(75,24,'max=%.2f' %DT_Vn_FEA_max, fontsize=8, color='k')
ax2.text(75,16,'mean=%.2f' %DT_Vn_FEA_mean, fontsize=8, color='k')
ax2.text(75,8,'COV=%.3f' %DT_Vn_FEA_COV, fontsize=8, color='k')

#------------------------------------------------------------------------------
#  RF
#------------------------------------------------------------------------------

ax3 = f1.add_subplot(3,3,3)
ax3.scatter(0.001*Y_Vn_RF, 0.001*Y_Vn, s=20, edgecolors='b', facecolor='none', linewidth=0.5, alpha=1)
ax3.set_aspect('equal')
ax3.set_xlabel('Vn (Prediction) (kN)', fontsize=9)
ax3.set_ylabel('Vn (FEA) (kN)', fontsize=9)
ax3.xaxis.set_ticks(np.arange(0, 121, 20))
ax3.yaxis.set_ticks(np.arange(0, 121, 20))
ax3.tick_params(axis='both', which='major', labelsize=9, direction='in', width=0.5)
for axis in ['top','bottom','left','right']:
  ax3.spines[axis].set_linewidth(0.5)

line = mlines.Line2D([0, 1], [0, 1], color='r', linestyle=':', linewidth=0.75, alpha=1)
transform = ax3.transAxes
line.set_transform(transform)
ax3.add_line(line)
ax3.text(20,100,'RF', fontsize=8, color='k')
ax3.text(10,80,'$R^2$=%.3f' %R2_RF_Vn, fontsize=8, color='k')
ax3.text(70,40,'Prediction/FEA', fontsize=8, color='k')
ax3.text(75,32,'min=%.2f' %RF_Vn_FEA_min, fontsize=8, color='k')
ax3.text(75,24,'max=%.2f' %RF_Vn_FEA_max, fontsize=8, color='k')
ax3.text(75,16,'mean=%.2f' %RF_Vn_FEA_mean, fontsize=8, color='k')
ax3.text(75,8,'COV=%.3f' %RF_Vn_FEA_COV, fontsize=8, color='k')


#------------------------------------------------------------------------------
#  KNN
#------------------------------------------------------------------------------

ax4 = f1.add_subplot(3,3,4)
ax4.scatter(0.001*Y_Vn_KNN, 0.001*Y_Vn, s=20, edgecolors='b', facecolor='none', linewidth=0.5, alpha=1)
ax4.set_aspect('equal')
ax4.set_xlabel('Vn (Prediction) (kN)', fontsize=9)
ax4.set_ylabel('Vn (FEA) (kN)', fontsize=9)
ax4.xaxis.set_ticks(np.arange(0, 121, 20))
ax4.yaxis.set_ticks(np.arange(0, 121, 20))
ax4.tick_params(axis='both', which='major', labelsize=9, direction='in', width=0.5)
for axis in ['top','bottom','left','right']:
  ax4.spines[axis].set_linewidth(0.5)

line = mlines.Line2D([0, 1], [0, 1], color='r', linestyle=':', linewidth=0.75, alpha=1)
transform = ax4.transAxes
line.set_transform(transform)
ax4.add_line(line)
ax4.text(20,100,'KNN', fontsize=8, color='k')
ax4.text(10,80,'$R^2$=%.3f' %R2_KNN_Vn, fontsize=8, color='k')
ax4.text(70,40,'Prediction/FEA', fontsize=8, color='k')
ax4.text(75,32,'min=%.2f' %KNN_Vn_FEA_min, fontsize=8, color='k')
ax4.text(75,24,'max=%.2f' %KNN_Vn_FEA_max, fontsize=8, color='k')
ax4.text(75,16,'mean=%.2f' %KNN_Vn_FEA_mean, fontsize=8, color='k')
ax4.text(75,8,'COV=%.3f' %KNN_Vn_FEA_COV, fontsize=8, color='k')

#------------------------------------------------------------------------------
#  GBR
#------------------------------------------------------------------------------

ax5 = f1.add_subplot(3,3,5)
ax5.scatter(0.001*Y_Vn_GBR, 0.001*Y_Vn, s=20, edgecolors='b', facecolor='none', linewidth=0.5, alpha=1)
ax5.set_aspect('equal')
ax5.set_xlabel('Vn (Prediction) (kN)', fontsize=9)
ax5.set_ylabel('Vn (FEA) (kN)', fontsize=9)
ax5.xaxis.set_ticks(np.arange(0, 121, 20))
ax5.yaxis.set_ticks(np.arange(0, 121, 20))
ax5.tick_params(axis='both', which='major', labelsize=9, direction='in', width=0.5)
for axis in ['top','bottom','left','right']:
  ax5.spines[axis].set_linewidth(0.5)

line = mlines.Line2D([0, 1], [0, 1], color='r', linestyle=':', linewidth=0.75, alpha=1)
transform = ax5.transAxes
line.set_transform(transform)
ax5.add_line(line)
ax5.text(20,100,'GBR', fontsize=8, color='k')
ax5.text(10,80,'$R^2$=%.3f' %R2_GBR_Vn, fontsize=8, color='k')
ax5.text(70,40,'Prediction/FEA', fontsize=8, color='k')
ax5.text(75,32,'min=%.2f' %GBR_Vn_FEA_min, fontsize=8, color='k')
ax5.text(75,24,'max=%.2f' %GBR_Vn_FEA_max, fontsize=8, color='k')
ax5.text(75,16,'mean=%.2f' %GBR_Vn_FEA_mean, fontsize=8, color='k')
ax5.text(75,8,'COV=%.3f' %GBR_Vn_FEA_COV, fontsize=8, color='k')

#------------------------------------------------------------------------------
#  XGBoost
#------------------------------------------------------------------------------

ax6 = f1.add_subplot(3,3,6)
ax6.scatter(0.001*Y_Vn_XGBoost, 0.001*Y_Vn, s=20, edgecolors='b', facecolor='none', linewidth=0.5, alpha=1)
ax6.set_aspect('equal')
ax6.set_xlabel('Vn (Prediction) (kN)', fontsize=9)
ax6.set_ylabel('Vn (FEA) (kN)', fontsize=9)
ax6.xaxis.set_ticks(np.arange(0, 121, 20))
ax6.yaxis.set_ticks(np.arange(0, 121, 20))
ax6.tick_params(axis='both', which='major', labelsize=9, direction='in', width=0.5)
for axis in ['top','bottom','left','right']:
  ax6.spines[axis].set_linewidth(0.5)

line = mlines.Line2D([0, 1], [0, 1], color='r', linestyle=':', linewidth=0.75, alpha=1)
transform = ax6.transAxes
line.set_transform(transform)
ax6.add_line(line)
ax6.text(20,100,'XGBoost', fontsize=8, color='k')
ax6.text(10,80,'$R^2$=%.3f' %R2_XGBoost_Vn, fontsize=8, color='k')
ax6.text(70,40,'Prediction/FEA', fontsize=8, color='k')
ax6.text(75,32,'min=%.2f' %XGBoost_Vn_FEA_min, fontsize=8, color='k')
ax6.text(75,24,'max=%.2f' %XGBoost_Vn_FEA_max, fontsize=8, color='k')
ax6.text(75,16,'mean=%.2f' %XGBoost_Vn_FEA_mean, fontsize=8, color='k')
ax6.text(75,8,'COV=%.3f' %XGBoost_Vn_FEA_COV, fontsize=8, color='k')

#------------------------------------------------------------------------------
#  LightGBM
#------------------------------------------------------------------------------

ax7 = f1.add_subplot(3,3,7)
ax7.scatter(0.001*Y_Vn_LightGBM, 0.001*Y_Vn, s=20, edgecolors='b', facecolor='none', linewidth=0.5, alpha=1)
ax7.set_aspect('equal')
ax7.set_xlabel('Vn (Prediction) (kN)', fontsize=9)
ax7.set_ylabel('Vn (FEA) (kN)', fontsize=9)
ax7.xaxis.set_ticks(np.arange(0, 121, 20))
ax7.yaxis.set_ticks(np.arange(0, 121, 20))
ax7.tick_params(axis='both', which='major', labelsize=9, direction='in', width=0.5)
for axis in ['top','bottom','left','right']:
  ax7.spines[axis].set_linewidth(0.5)

line = mlines.Line2D([0, 1], [0, 1], color='r', linestyle=':', linewidth=0.75, alpha=1)
transform = ax7.transAxes
line.set_transform(transform)
ax7.add_line(line)
ax7.text(20,100,'LightGBM', fontsize=8, color='k')
ax7.text(10,80,'$R^2$=%.3f' %R2_LightGBM_Vn, fontsize=8, color='k')
ax7.text(70,40,'Prediction/FEA', fontsize=8, color='k')
ax7.text(75,32,'min=%.2f' %LightGBM_Vn_FEA_min, fontsize=8, color='k')
ax7.text(75,24,'max=%.2f' %LightGBM_Vn_FEA_max, fontsize=8, color='k')
ax7.text(75,16,'mean=%.2f' %LightGBM_Vn_FEA_mean, fontsize=8, color='k')
ax7.text(75,8,'COV=%.3f' %LightGBM_Vn_FEA_COV, fontsize=8, color='k')

#------------------------------------------------------------------------------
#  CatBoost
#------------------------------------------------------------------------------

ax8 = f1.add_subplot(3,3,8)
ax8.scatter(0.001*Y_Vn_CatBoost, 0.001*Y_Vn, s=20, edgecolors='b', facecolor='none', linewidth=0.5, alpha=1)
ax8.set_aspect('equal')
ax8.set_xlabel('Vn (Prediction) (kN)', fontsize=9)
ax8.set_ylabel('Vn (FEA) (kN)', fontsize=9)
ax8.xaxis.set_ticks(np.arange(0, 121, 20))
ax8.yaxis.set_ticks(np.arange(0, 121, 20))
ax8.tick_params(axis='both', which='major', labelsize=9, direction='in', width=0.5)
for axis in ['top','bottom','left','right']:
  ax8.spines[axis].set_linewidth(0.5)

line = mlines.Line2D([0, 1], [0, 1], color='r', linestyle=':', linewidth=0.75, alpha=1)
transform = ax8.transAxes
line.set_transform(transform)
ax8.add_line(line)
ax8.text(20,100,'CatBoost', fontsize=8, color='k')
ax8.text(10,80,'$R^2$=%.3f' %R2_CatBoost_Vn, fontsize=8, color='k')
ax8.text(70,40,'Prediction/FEA', fontsize=8, color='k')
ax8.text(75,32,'min=%.2f' %CatBoost_Vn_FEA_min, fontsize=8, color='k')
ax8.text(75,24,'max=%.2f' %CatBoost_Vn_FEA_max, fontsize=8, color='k')
ax8.text(75,16,'mean=%.2f' %CatBoost_Vn_FEA_mean, fontsize=8, color='k')
ax8.text(75,8,'COV=%.3f' %CatBoost_Vn_FEA_COV, fontsize=8, color='k')

#------------------------------------------------------------------------------
#  AdaBoost
#------------------------------------------------------------------------------

ax9 = f1.add_subplot(3,3,9)
ax9.scatter(0.001*Y_Vn_AdaBoost, 0.001*Y_Vn, s=20, edgecolors='b', facecolor='none', linewidth=0.5, alpha=1)
ax9.set_aspect('equal')
ax9.set_xlabel('Vn (Prediction) (kN)', fontsize=9)
ax9.set_ylabel('Vn (FEA) (kN)', fontsize=9)
ax9.xaxis.set_ticks(np.arange(0, 121, 20))
ax9.yaxis.set_ticks(np.arange(0, 121, 20))
ax9.tick_params(axis='both', which='major', labelsize=9, direction='in', width=0.5)
for axis in ['top','bottom','left','right']:
  ax9.spines[axis].set_linewidth(0.5)

line = mlines.Line2D([0, 1], [0, 1], color='r', linestyle=':', linewidth=0.75, alpha=1)
transform = ax9.transAxes
line.set_transform(transform)
ax9.add_line(line)
ax9.text(20,100,'AdaBoost', fontsize=8, color='k')
ax9.text(10,80,'$R^2$=%.3f' %R2_AdaBoost_Vn, fontsize=8, color='k')
ax9.text(70,40,'Prediction/FEA', fontsize=8, color='k')
ax9.text(75,32,'min=%.2f' %AdaBoost_Vn_FEA_min, fontsize=8, color='k')
ax9.text(75,24,'max=%.2f' %AdaBoost_Vn_FEA_max, fontsize=8, color='k')
ax9.text(75,16,'mean=%.2f' %AdaBoost_Vn_FEA_mean, fontsize=8, color='k')
ax9.text(75,8,'COV=%.3f' %AdaBoost_Vn_FEA_COV, fontsize=8, color='k')

f1.tight_layout()
plt.show()

# %%
#Range of applicability
D_min=np.ndarray.min(X_Vn[:,0])
D_max=np.ndarray.max(X_Vn[:,0])

B_min=np.ndarray.min(X_Vn[:,1])
B_max=np.ndarray.max(X_Vn[:,1])

t_min=np.ndarray.min(X_Vn[:,2])
t_max=np.ndarray.max(X_Vn[:,2])

Lsl_min=np.ndarray.min(X_Vn[:,3])
Lsl_max=np.ndarray.max(X_Vn[:,3])

Wsl_min=np.ndarray.min(X_Vn[:,4])
Wsl_max=np.ndarray.max(X_Vn[:,4])

Ssl_min=np.ndarray.min(X_Vn[:,5])
Ssl_max=np.ndarray.max(X_Vn[:,5])

Bsl_min=np.ndarray.min(X_Vn[:,6])
Bsl_max=np.ndarray.max(X_Vn[:,6])

N_min=np.ndarray.min(X_Vn[:,7])
N_max=np.ndarray.max(X_Vn[:,7])

n_min=np.ndarray.min(X_Vn[:,8])
n_max=np.ndarray.max(X_Vn[:,8])

Fy_min=np.ndarray.min(X_Vn[:,9])
Fy_max=np.ndarray.max(X_Vn[:,9])

a_h_min=np.ndarray.min(X_Vn[:,11])
a_h_max=np.ndarray.max(X_Vn[:,11])

hst_min=np.ndarray.min(X_Vn[:,12])
hst_max=np.ndarray.max(X_Vn[:,12])

print('The presented ML models are applicable to the following ranges of the input parameters')
print()
print('Channel depth, D (mm)')
print('Minimum: %.0f'% D_min)
print('Maximum: %.0f'% D_max)
print()
print('Channel flange width, B (mm)')
print('Minimum: %.0f'% B_min)
print('Maximum: %.0f'% B_max)   
print()
print('Channel thickness, t (mm)')
print('Minimum: %.0f'% t_min)
print('Maximum: %.0f'% t_max)     
print()
print('Perforation length, Lsl (mm)')
print('Minimum: %.0f'% Lsl_min)
print('Maximum: %.0f'% Lsl_max)   
print()
print('Perforation depth, Wsl (mm)')
print('Minimum: %.0f'% Wsl_min)
print('Maximum: %.0f'% Wsl_max)  
print()
print('Perforation center-to-center spacing along channel length, Ssl (mm)')
print('Minimum: %.0f'% Ssl_min)
print('Maximum: %.0f'% Ssl_max)  
print()
print('Perforation center-to-center spacing along channel depth, Bsl (mm)')
print('Minimum: %.0f'% Bsl_min)
print('Maximum: %.0f'% Bsl_max)  
print()
print('Number of perforated regions, N')
print('Minimum: %.0f'% N_min)
print('Maximum: %.0f'% N_max)  
print()
print('Number of perforation courses, n')
print('Minimum: %.0f'% n_min)
print('Maximum: %.0f'% n_max)  
print()
print('Steel yield strength, Fy (MPa)')
print('Minimum: %.0f'% Fy_min)
print('Maximum: %.0f'% Fy_max)
print()
print('Boundary conditions')
print('Realistic & Test setup')
print()
print('Aspect ratio, a/h')
print('Minimum: '+str(a_h_min))
print('Maximum: '+str(a_h_max))
print()
print('Longitudinal web stiffener height, hst (mm)')
print('Minimum: %.0f'% hst_min)
print('Maximum: %.0f'% hst_max)
# Out:
# The presented ML models are applicable to the following ranges of the input parameters
#
# Channel depth, D (mm)
# Minimum: 150
# Maximum: 250
#
# Channel flange width, B (mm)
# Minimum: 20
# Maximum: 95
#
# Channel thickness, t (mm)
# Minimum: 1
# Maximum: 3
#
# Perforation length, Lsl (mm)
# Minimum: 60
# Maximum: 90
#
# Perforation depth, Wsl (mm)
# Minimum: 3
# Maximum: 7
#
# Perforation center-to-center spacing along channel length, Ssl (mm)
# Minimum: 85
# Maximum: 115
#
# Perforation center-to-center spacing along channel depth, Bsl (mm)
# Minimum: 8
# Maximum: 12
#
# Number of perforated regions, N
# Minimum: 1
# Maximum: 2
#
# Number of perforation courses, n
# Minimum: 6
# Maximum: 12
#
# Steel yield strength, Fy (MPa)
# Minimum: 250
# Maximum: 500
#
# Boundary conditions
# Realistic & Test setup
#
# Aspect ratio, a/h
# Minimum: 0.5
# Maximum: 1.5
#
# Longitudinal web stiffener height, hst (mm)
# Minimum: 0
# Maximum: 60

# %%
#Predict elastic buckling and ultimate loads of cellular beams using the developed ML models

#Input parameters
D=150              #channel depth in mm
B=45               #channel flange width in mm
t=1                #channel thickness in mm
Lsl=60             #perforation length in mm
Wsl=3              #perforation depth in mm
Ssl=100            #perforation center-to-center spacing along channel length in mm
Bsl=9.5            #perforation center-to-center spacing along channel depth in mm
N=1                #number of perforated regions
n=6                #number of perforation courses
Fy=500             #steel yield strength in MPa
BC=1               #boundary conditions (1 for realistic and 2 for test setup)
a_h=1              #aspect ratio
hst=0              #longitudinal web stiffener height

# %%
X_IP_Vcr=np.array([[D,B,t,Lsl,Wsl,Ssl,Bsl,N,n,BC,a_h,hst]])
X_IP_Vn=np.array([[D,B,t,Lsl,Wsl,Ssl,Bsl,N,n,Fy,BC,a_h,hst]])

X_IP_Vcr_SVR=SVR_Vcr_scaler.transform(X_IP_Vcr)
X_IP_Vcr_DT=DT_Vcr_scaler.transform(X_IP_Vcr)
X_IP_Vcr_RF=RF_Vcr_scaler.transform(X_IP_Vcr)
X_IP_Vcr_KNN=KNN_Vcr_scaler.transform(X_IP_Vcr)
X_IP_Vcr_GBR=GBR_Vcr_scaler.transform(X_IP_Vcr)
X_IP_Vcr_XGBoost=XGBoost_Vcr_scaler.transform(X_IP_Vcr)
X_IP_Vcr_LightGBM=LightGBM_Vcr_scaler.transform(X_IP_Vcr)
X_IP_Vcr_CatBoost=CatBoost_Vcr_scaler.transform(X_IP_Vcr)
X_IP_Vcr_AdaBoost=AdaBoost_Vcr_scaler.transform(X_IP_Vcr)

X_IP_Vn_SVR=SVR_Vn_scaler.transform(X_IP_Vn)
X_IP_Vn_DT=DT_Vn_scaler.transform(X_IP_Vn)
X_IP_Vn_RF=RF_Vn_scaler.transform(X_IP_Vn)
X_IP_Vn_KNN=KNN_Vn_scaler.transform(X_IP_Vn)
X_IP_Vn_GBR=GBR_Vn_scaler.transform(X_IP_Vn)
X_IP_Vn_XGBoost=XGBoost_Vn_scaler.transform(X_IP_Vn)
X_IP_Vn_LightGBM=LightGBM_Vn_scaler.transform(X_IP_Vn)
X_IP_Vn_CatBoost=CatBoost_Vn_scaler.transform(X_IP_Vn)
X_IP_Vn_AdaBoost=AdaBoost_Vn_scaler.transform(X_IP_Vn)

Vcr_SVR=0.001*SVR_Vcr_model.predict(X_IP_Vcr_SVR)
Vcr_DT=0.001*DT_Vcr_model.predict(X_IP_Vcr_DT)
Vcr_RF=0.001*RF_Vcr_model.predict(X_IP_Vcr_RF)
Vcr_KNN=0.001*KNN_Vcr_model.predict(X_IP_Vcr_KNN)
Vcr_GBR=0.001*GBR_Vcr_model.predict(X_IP_Vcr_GBR)
Vcr_XGBoost=0.001*XGBoost_Vcr_model.predict(X_IP_Vcr_XGBoost)
Vcr_LightGBM=0.001*LightGBM_Vcr_model.predict(X_IP_Vcr_LightGBM)
Vcr_CatBoost=0.001*CatBoost_Vcr_model.predict(X_IP_Vcr_CatBoost)
Vcr_AdaBoost=0.001*AdaBoost_Vcr_model.predict(X_IP_Vcr_AdaBoost)

Vn_SVR=0.001*SVR_Vn_model.predict(X_IP_Vn_SVR)
Vn_DT=0.001*DT_Vn_model.predict(X_IP_Vn_DT)
Vn_RF=0.001*RF_Vn_model.predict(X_IP_Vn_RF)
Vn_KNN=0.001*KNN_Vn_model.predict(X_IP_Vn_KNN)
Vn_GBR=0.001*GBR_Vn_model.predict(X_IP_Vn_GBR)
Vn_XGBoost=0.001*XGBoost_Vn_model.predict(X_IP_Vn_XGBoost)
Vn_LightGBM=0.001*LightGBM_Vn_model.predict(X_IP_Vn_LightGBM)
Vn_CatBoost=0.001*CatBoost_Vn_model.predict(X_IP_Vn_CatBoost)
Vn_AdaBoost=0.001*AdaBoost_Vn_model.predict(X_IP_Vn_AdaBoost)

# %%
print('SVR')
print('Vcr=%.2f'% Vcr_SVR[0]+' kN')
print('Vn=%.2f'% Vn_SVR[0]+' kN')
print()

print('DT')
print('Vcr=%.2f'% Vcr_DT[0]+' kN')
print('Vn=%.2f'% Vn_DT[0]+' kN')
print()

print('RF')
print('Vcr=%.2f'% Vcr_RF[0]+' kN')
print('Vn=%.2f'% Vn_RF[0]+' kN')
print()

print('KNN')
print('Vcr=%.2f'% Vcr_KNN[0]+' kN')
print('Vn=%.2f'% Vn_KNN[0]+' kN')
print()

print('GBR')
print('Vcr=%.2f'% Vcr_GBR[0]+' kN')
print('Vn=%.2f'% Vn_GBR[0]+' kN')
print()

print('XGBoost')
print('Vcr=%.2f'% Vcr_XGBoost[0]+' kN')
print('Vn=%.2f'% Vn_XGBoost[0]+' kN')
print()

print('LightGBM')
print('Vcr=%.2f'% Vcr_LightGBM[0]+' kN')
print('Vn=%.2f'% Vn_LightGBM[0]+' kN')
print()

print('CatBoost')
print('Vcr=%.2f'% Vcr_CatBoost[0]+' kN')
print('Vn=%.2f'% Vn_CatBoost[0]+' kN')
print()

print('AdaBoost')
print('Vcr=%.2f'% Vcr_AdaBoost[0]+' kN')
print('Vn=%.2f'% Vn_AdaBoost[0]+' kN')
# Out:
# SVR
# Vcr=5.23 kN
# Vn=10.77 kN
#
# DT
# Vcr=4.72 kN
# Vn=10.49 kN
#
# RF
# Vcr=4.76 kN
# Vn=10.65 kN
#
# KNN
# Vcr=17.57 kN
# Vn=19.80 kN
#
# GBR
# Vcr=5.04 kN
# Vn=10.89 kN
#
# XGBoost
# Vcr=5.70 kN
# Vn=11.43 kN
#
# LightGBM
# Vcr=4.85 kN
# Vn=10.80 kN
#
# CatBoost
# Vcr=5.48 kN
# Vn=10.73 kN
#
# AdaBoost
# Vcr=5.09 kN
# Vn=11.86 kN
